# %%
import pandas as pd
from PIL import Image
import cv2

# %%
full_labels = pd.read_csv("output.csv",header=None);
full_labels.columns = [['filename','plate_number','xmin', 'ymin', 'xmax', 'ymax']]
#full_labels.to_csv("output2.csv", encoding='utf-8')
full_labels
# Out:
#   filename plate_number  xmin  ymin  xmax  ymax
# 0    0.png     EJB-9268    99     2   599   207
# 1    1.png     ZJN-0054   155    61   655   266
# 2    2.png     LLZ-1418    64   186   564   391

# %%
def draw_boxes(image_name):
    selected_value = full_labels[full_labels.filename == image_name]
    img = cv2.imread('plate_gen/{}'.format(image_name))
    for index, row in selected_value.iterrows():
        img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
    return img

# %%
Image.fromarray(draw_boxes('1.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=640x426 at 0x1206E1C50>
