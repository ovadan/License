# %%
import pandas

# %%
dataSet = pandas.read_csv("output.csv",header=None);
dataSet.columns = [['plate_number','x', 'y', 'x2', 'y2','']]
dataSet.head(n=50)
# Out:
#    plate_number    x    y   x2   y2
# 0      POG-1391   70   56  570  261 NaN
# 1      TMW-6617  139   12  639  217 NaN
# 2      JKS-1502  130  164  630  369 NaN
# 3      KND-7727  114  124  614  329 NaN
# 4      BBN-0962  103  150  603  355 NaN
# 5      ZFV-9035  157  175  657  380 NaN
# 6      EUK-6175   19  116  519  321 NaN
# 7      OMO-3947   53   96  553  301 NaN
# 8      LEG-1321  173  152  673  357 NaN
# 9      RIY-2941  118   38  618  243 NaN
# 10     YOS-6688   26   24  526  229 NaN
# 11     GUW-2594    3  136  503  341 NaN
# 12     TMU-5533   14   37  514  242 NaN
# 13     KZB-3678  165  157  665  362 NaN
# 14     YRN-7222   32  139  532  344 NaN
# 15     QIG-9051   76  112  576  317 NaN
# 16     MZF-3041  137  117  637  322 NaN
# 17     CPB-1573  149  135  649  340 NaN
# 18     EFA-4605   33   77  533  282 NaN
# 19     RCY-4091   84   27  584  232 NaN
# 20     MGD-6278  108   77  608  282 NaN
# 21     VFQ-3068  173   27  673  232 NaN
# ...
